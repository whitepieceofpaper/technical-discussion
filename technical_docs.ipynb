# %% [markdown]
# <a href="https://colab.research.google.com/github/whitepieceofpaper/technical-discussion/blob/main/technical_docs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest

# %%
def hello():
  return "hi"
hello()
# Out:
# 'hi'
